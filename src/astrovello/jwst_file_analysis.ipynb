# %%
import numpy as np
from astropy.io import fits
from pathlib import Path
import matplotlib.pyplot as plt

# %%
np.sqrt(0.003968755027958104 )
# Out:
# np.float64(0.06299805574744433)

# %%
CWD = Path.cwd()
ROOT = CWD.parents[1] 

# jwst_dir = ROOT / "Input" / "PHANGS" / "galaxies" / "ngc1087" / "hlsp_phangs-jwst_jwst_miri-nircam_ngc1087_multi_v1p1_img"
jwst_dir = ROOT / "Input" / "PHANGS" / "galaxies" / "ngc1087"

# %%
jwst_dir = list(jwst_dir.glob(".fits"))

# %%
with fits.open(jwst_files[0]) as hdu:
    hdu.info()
    header = hdu[0].header

    sci_img = hdu[1].data
    sci_header = hdu[1].header

    err_img = hdu[2].data
    err_header = hdu[2].header
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 with fits.open(jwst_files[0]) as hdu:
#       2     hdu.info()
#       3     header = hdu[0].header
#       4
#
# IndexError: list index out of range

# %%
err_header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 1640
# NAXIS2  =                 2017
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'ERR     '           / extension name
# BUNIT   = 'MJy/sr  '           / physical units of the array values
# EXTVER  =                    1 / extension value

# %%
print(np.sqrt(0.012300004284764113))
# Out:
# 0.11090538438130096

# %%
vmin, vmax = np.percentile(sci_img, [5,95])

plt.figure()
plt.imshow(sci_img, cmap = "viridis", origin = 'lower', vmin=vmin, vmax=vmax)
plt.show()
